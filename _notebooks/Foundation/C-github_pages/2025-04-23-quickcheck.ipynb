# %% [markdown]
# ---
# toc: true
# comments: false
# layout: post
# title: "AP CSP Study Plan"
# type: ccc
# permalink: /quickcheck
# ---

# %% [markdown]
# ## 📅 AP Exam Prep Plan: April to May
#
# With the AP exam fast approaching, I’ve created a focused plan to juggle both project deadlines and studying. Here's the breakdown:
#
# ---
#
# ### 🛠️ April: Making Projects & Transitioning to Study Mode
#
# The first half of April was centered on development. I wrapped up key tasks like working with my team to develop our frontend UI and set up databases.
#
# ---
#
# ### 📚 Late April: Deep Focus on Big Ideas
#
# Starting April 22, I shifted fully into AP prep mode. The plan includes:
#
# - Daily review sessions covering Big Ideas 1–5
# - Reinforcement with Khan Academy modules
# - Spaced scheduling to support deeper understanding
#
# ---
#
# ### 📝 End of April – Early May: Practice Mode
#
# Starting April 27, the focus turns to practice:
#
# - **April 28**: Finalize FRQ wording and submit to CollegeBoard
# - **May 1–3**: Multiple Choice Practice Tests
# - **May 9–13**: More MC tests and full review of Big Ideas
# - **May 14**: Full practice AP exam
#
# ---
#
# ### 🎯 May 15: The AP Exam
#
# The big day! My schedule is designed to peak just before the test, with light reviews and a full simulation in the final days.

# %% [markdown]
# ## 🧠 AP CSP Big Ideas Study Schedule (April 23 – May 14)
#
# | Date       | Focus Topic                        | Notes / Activity                                       |
# |------------|------------------------------------|--------------------------------------------------------|
# | Apr 23     | Big Idea 1: Creative Development   | Overview + Key vocab + Examples of computing innovations |
# | Apr 24     | Big Idea 1: Continued              | Explore program design, pair programming, pseudocode   |
# | Apr 25     | Big Idea 2: Data                   | Types of data, data abstraction, and binary encoding   |
# | Apr 26     | Big Idea 2: Continued              | Data analysis, visualization, lossless/lossy compression |
# | Apr 27     | Review Day                         | Recap Big Ideas 1 & 2 with practice questions           |
# | Apr 28     | FRQ Polishing + Submission         | Focus on clarity, formatting, and final touches         |
# | Apr 29     | Big Idea 3: Algorithms & Programming | Conditionals, loops, functions, parameters             |
# | Apr 30     | Big Idea 3: Continued              | Lists, procedures, algorithm efficiency                |
# | May 1–3    | Multiple Choice Practice Tests     | Timed MCQs based on Big Ideas 1–3                      |
# | May 4      | Big Idea 4: Computer Systems & Networks | The internet, protocols, fault tolerance           |
# | May 5      | Big Idea 4: Continued              | Cybersecurity, encryption, safe computing              |
# | May 6      | Review Day                         | Recap Big Ideas 3 & 4 with mixed practice               |
# | May 7      | Big Idea 5: Impact of Computing    | Analyze computing’s effects on culture/society         |
# | May 8      | Big Idea 5: Continued              | Legal, ethical, and bias considerations in computing   |
# | May 9–10   | Mixed Review (Ideas 1–5)           | MC + Concept check-ins, flashcards, peer discussions   |
# | May 11     | Practice FRQs                      | Target weak spots, practice explaining algorithms      |
# | May 12     | Full Concept Review                | Review summaries, mind maps, reinforce key themes      |
# | May 13     | Light Practice Test / Simulation   | Final run-through with timed conditions                |
# | May 14     | Relaxed Review + Confidence Boost  | Skim notes, review starred Qs, sleep early             |
# | **May 15** | **🎯 AP Exam Day**                  | You got this! Go in calm, confident, and focused       |

# %%
import ipywidgets as widgets
from IPython.display import display, Markdown

topics = [
    ("Apr 23", "Big Idea 1: Creative Development"),
    ("Apr 24", "Big Idea 1: Continued"),
    ("Apr 25", "Big Idea 2: Data"),
    ("Apr 26", "Big Idea 2: Continued"),
    ("Apr 27", "Review Day"),
    ("Apr 28", "FRQ Polishing + Submission"),
    ("Apr 29", "Big Idea 3: Algorithms & Programming"),
    ("Apr 30", "Big Idea 3: Continued"),
    ("May 1–3", "Multiple Choice Practice Tests"),
    ("May 4", "Big Idea 4: Computer Systems & Networks"),
    ("May 5", "Big Idea 4: Continued"),
    ("May 6", "Review Day"),
    ("May 7", "Big Idea 5: Impact of Computing"),
    ("May 8", "Big Idea 5: Continued"),
    ("May 9–10", "Mixed Review (Ideas 1–5)"),
    ("May 11", "Practice FRQs"),
    ("May 12", "Full Concept Review"),
    ("May 13", "Light Practice Test / Simulation"),
    ("May 14", "Relaxed Review + Confidence Boost"),
    ("May 15", "🎯 AP Exam Day")
]

checkboxes = []
for date, topic in topics:
    cb = widgets.Checkbox(value=False, description=f"{date} — {topic}")
    checkboxes.append(cb)
    display(cb)
